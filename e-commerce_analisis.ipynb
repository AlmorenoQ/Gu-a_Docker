# %%
from sqlalchemy import create_engine, text
import pandas as pd

# Crea tu conexión (ajusta estos parámetros según tu configuración)
engine = create_engine("postgresql://postgres:micontraseña@localhost:5432/analisis_datos")

# %%
# Reiniciar ecommerce
with engine.connect() as conn:
    conn.execute(text("DROP SCHEMA IF EXISTS ecommerce CASCADE;"))
    conn.commit()

# %%
with engine.connect() as conn:
    conn.execute(text("CREATE SCHEMA IF NOT EXISTS ecommerce"))
    conn.commit()

# %%
tablas_sql = """
-- Tabla de categorías de productos
CREATE TABLE IF NOT EXISTS ecommerce.categorias (
    id_categoria SERIAL PRIMARY KEY,
    nombre VARCHAR(50) NOT NULL,
    descripcion TEXT
);

-- Tabla de productos
CREATE TABLE IF NOT EXISTS ecommerce.productos (
    id_producto SERIAL PRIMARY KEY,
    id_categoria INTEGER REFERENCES ecommerce.categorias(id_categoria),
    nombre VARCHAR(100) NOT NULL,
    descripcion TEXT,
    precio NUMERIC(10,2) NOT NULL,
    costo NUMERIC(10,2) NOT NULL,
    stock INTEGER NOT NULL DEFAULT 0,
    fecha_creacion TIMESTAMP DEFAULT CURRENT_TIMESTAMP
);

-- Tabla de clientes
CREATE TABLE IF NOT EXISTS ecommerce.clientes (
    id_cliente SERIAL PRIMARY KEY,
    nombre VARCHAR(100) NOT NULL,
    email VARCHAR(100) UNIQUE NOT NULL,
    fecha_registro TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    ciudad VARCHAR(100),
    pais VARCHAR(50),
    genero VARCHAR(20),
    edad INTEGER
);

-- Tabla de pedidos
CREATE TABLE IF NOT EXISTS ecommerce.pedidos (
    id_pedido SERIAL PRIMARY KEY,
    id_cliente INTEGER REFERENCES ecommerce.clientes(id_cliente),
    fecha_pedido TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
    estado VARCHAR(20) CHECK (estado IN ('Pendiente', 'Enviado', 'Entregado', 'Cancelado')),
    metodo_pago VARCHAR(50),
    total NUMERIC(12,2) NOT NULL
);

-- Tabla de detalles de pedidos (líneas de pedido)
CREATE TABLE IF NOT EXISTS ecommerce.detalles_pedido (
    id_detalle SERIAL PRIMARY KEY,
    id_pedido INTEGER REFERENCES ecommerce.pedidos(id_pedido),
    id_producto INTEGER REFERENCES ecommerce.productos(id_producto),
    cantidad INTEGER NOT NULL,
    precio_unitario NUMERIC(10,2) NOT NULL,
    subtotal NUMERIC(12,2) NOT NULL
);
"""

with engine.connect() as conn:
    conn.execute(text(tablas_sql))
    conn.commit()

# %%
# Listar tablas
query = """ 
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'ecommerce'
    ORDER BY table_name;
"""

# %%
with engine.connect() as conn:
    result = conn.execute(text(query))
    tables = [row[0] for row in result]
    print(tables)
# Out:
# ['categorias', 'clientes', 'detalles_pedido', 'pedidos', 'productos']

# %%
# Crea un DataFrame con categorías relevantes para una tienda online
categorias = pd.DataFrame({
    'nombre': ['Electrónica', 'Ropa', 'Hogar', 'Deportes', 'Libros'],
    'descripcion': [
        'Productos electrónicos y gadgets',
        'Ropa y accesorios',
        'Artículos para el hogar',
        'Equipamiento deportivo',
        'Libros y publicaciones'
    ]
})

# Guarda a CSV para uso futuro
categorias.to_csv('categorias.csv', index=False)

# %%
import numpy as np

np.random.seed(42)
productos = []

# %%
import random

for i in range(1, 51):
    id_categoria = random.randint(1, 5)
    if id_categoria == 1:  # Electrónica
        nombre = random.choice(['Smartphone', 'Laptop', 'Tablet', 'Auriculares', 'Smartwatch']) + f" Modelo {i}"
        precio_base = random.uniform(300, 1500)
    elif id_categoria == 2:  # Ropa
        nombre = random.choice(['Camiseta', 'Pantalón', 'Vestido', 'Chaqueta', 'Zapatos']) + f" Estilo {i}"
        precio_base = random.uniform(20, 150)
    elif id_categoria == 3:  # Hogar
        nombre = random.choice(['Lámpara', 'Sofá', 'Mesa', 'Vajilla', 'Cortinas']) + f" Home {i}"
        precio_base = random.uniform(50, 800)
    elif id_categoria == 4:  # Deportes
        nombre = random.choice(['Balón', 'Raqueta', 'Zapatillas', 'Bicicleta', 'Mancuernas']) + f" Pro {i}"
        precio_base = random.uniform(30, 500)
    else:
        nombre = random.choice(['Novela', 'Biografía', 'Ciencia', 'Historia', 'Cocina']) + f" Vol. {i}"
        precio_base = random.uniform(10, 50)

    precio = round(precio_base, 2)
    costo = round(precio * random.uniform(0.4, 0.7), 2) # Costo entre 40-70% del precio

    productos.append({
         'id_categoria': id_categoria,
        'nombre': nombre,
        'descripcion': f"Descripción del producto {nombre}",
        'precio': precio,
        'costo': costo,
        'stock': random.randint(0, 100)
    })

df_productos = pd.DataFrame(productos)
df_productos
# Out:
#     id_categoria                 nombre  \
# 0              2       Vestido Estilo 1
# 1              5       Biografía Vol. 2
# 2              2      Pantalón Estilo 3
# 3              4       Zapatillas Pro 4
# 4              4        Bicicleta Pro 5
# 5              1   Auriculares Modelo 6
# 6              1        Laptop Modelo 7
# 7              2       Vestido Estilo 8
# 8              2      Chaqueta Estilo 9
# 9              2     Camiseta Estilo 10
# 10             3           Sofá Home 11
# 11             3        Lámpara Home 12
# 12             4           Balón Pro 13
# 13             4       Bicicleta Pro 14
# 14             3           Mesa Home 15
# 15             1  Auriculares Modelo 16
# 16             2      Vestido Estilo 17
# 17             2     Chaqueta Estilo 18
# 18             2     Chaqueta Estilo 19
# 19             3           Mesa Home 20
# 20             4       Bicicleta Pro 21
# 21             4       Bicicleta Pro 22
# 22             1   Smartwatch Modelo 23
# 23             2      Zapatos Estilo 24
# 24             3           Mesa Home 25
# 25             3           Mesa Home 26
# 26             3        Vajilla Home 27
# 27             3        Vajilla Home 28
# 28             5       Historia Vol. 29
# 29             1   Smartphone Modelo 30
# 30             1       Tablet Modelo 31
# 31             2      Vestido Estilo 32
# 32             4      Mancuernas Pro 33
# 33             2     Camiseta Estilo 34
# 34             4      Mancuernas Pro 35
# 35             1       Tablet Modelo 36
# 36             3        Lámpara Home 37
# 37             2      Vestido Estilo 38
# 38             5         Novela Vol. 39
# 39             2     Chaqueta Estilo 40
# 40             4         Raqueta Pro 41
# 41             5        Ciencia Vol. 42
# 42             1       Laptop Modelo 43
# 43             5         Novela Vol. 44
# 44             1   Smartwatch Modelo 45
# 45             1       Laptop Modelo 46
# 46             2     Pantalón Estilo 47
# 47             3        Vajilla Home 48
# 48             5        Ciencia Vol. 49
# 49             1       Tablet Modelo 50
#
#                                        descripcion   precio   costo  stock
# 0        Descripción del producto Vestido Estilo 1   140.46   79.15     72
# 1        Descripción del producto Biografía Vol. 2    27.00   16.01      9
# 2       Descripción del producto Pantalón Estilo 3    64.94   32.69     63
# 3        Descripción del producto Zapatillas Pro 4   244.67  139.05     96
# 4         Descripción del producto Bicicleta Pro 5   114.22   50.62     54
# 5    Descripción del producto Auriculares Modelo 6   343.99  224.80     48
# 6         Descripción del producto Laptop Modelo 7  1222.76  707.20     20
# 7        Descripción del producto Vestido Estilo 8   140.14   90.02     93
# 8       Descripción del producto Chaqueta Estilo 9    24.02   13.54      9
# 9      Descripción del producto Camiseta Estilo 10    88.07   57.69     65
# 10           Descripción del producto Sofá Home 11   398.81  246.75     42
# 11        Descripción del producto Lámpara Home 12   656.46  352.16     77
# 12           Descripción del producto Balón Pro 13    95.57   51.28     56
# 13       Descripción del producto Bicicleta Pro 14   178.71  121.84     78
# 14           Descripción del producto Mesa Home 15   175.34   93.30      6
# 15  Descripción del producto Auriculares Modelo 16  1425.40  626.75      7
# 16      Descripción del producto Vestido Estilo 17    75.91   47.50     80
# 17     Descripción del producto Chaqueta Estilo 18   141.58   89.76     84
# 18     Descripción del producto Chaqueta Estilo 19   121.10   51.54     80
# 19           Descripción del producto Mesa Home 20   311.96  201.80     90
# 20       Descripción del producto Bicicleta Pro 21   439.00  234.02     23
# 21       Descripción del producto Bicicleta Pro 22   446.82  212.57      8
# 22   Descripción del producto Smartwatch Modelo 23   796.47  383.12     33
# 23      Descripción del producto Zapatos Estilo 24    71.50   34.88     95
# 24           Descripción del producto Mesa Home 25   260.80  109.72     38
# 25           Descripción del producto Mesa Home 26    85.80   47.15     51
# 26        Descripción del producto Vajilla Home 27   556.45  322.30     91
# 27        Descripción del producto Vajilla Home 28   753.83  366.49     76
# 28       Descripción del producto Historia Vol. 29    45.12   25.44     59
# 29   Descripción del producto Smartphone Modelo 30   342.77  236.11     51
# 30       Descripción del producto Tablet Modelo 31  1475.20  912.11     84
# 31      Descripción del producto Vestido Estilo 32   138.04   85.08     33
# 32      Descripción del producto Mancuernas Pro 33   139.51   64.60     78
# 33     Descripción del producto Camiseta Estilo 34    71.90   36.85     39
# 34      Descripción del producto Mancuernas Pro 35    90.88   62.92     44
# 35       Descripción del producto Tablet Modelo 36  1377.54  774.54     22
# 36        Descripción del producto Lámpara Home 37   458.38  285.95      4
# 37      Descripción del producto Vestido Estilo 38   140.86   91.89     35
# 38         Descripción del producto Novela Vol. 39    36.93   22.85     21
# 39     Descripción del producto Chaqueta Estilo 40    79.75   46.24     28
# 40         Descripción del producto Raqueta Pro 41   213.93  128.81      9
# 41        Descripción del producto Ciencia Vol. 42    41.66   18.53      0
# 42       Descripción del producto Laptop Modelo 43  1051.93  587.49     12
# 43         Descripción del producto Novela Vol. 44    36.68   18.09     64
# 44   Descripción del producto Smartwatch Modelo 45   950.82  511.72     75
# 45       Descripción del producto Laptop Modelo 46   363.04  147.29     31
# 46     Descripción del producto Pantalón Estilo 47    75.45   49.67      3
# 47        Descripción del producto Vajilla Home 48   354.48  190.34     76
# 48        Descripción del producto Ciencia Vol. 49    11.45    6.11     14
# 49       Descripción del producto Tablet Modelo 50   954.64  485.34     53

# %%
df_productos.to_csv('productos.csv', index=False)

# %%
from datetime import datetime, timedelta
clientes = []
for i in range(1, 101):
    genero = random.choice(['Masculino', 'Femenino', 'No especificado'])
    if genero == 'Masculino':
        nombre = random.choice(['Juan', 'Carlos', 'Miguel', 'David', 'José']) + " " + \
                random.choice(['García', 'Rodríguez', 'López', 'Martínez', 'González'])
    elif genero == 'Femenino':
        nombre = random.choice(['Ana', 'María', 'Laura', 'Elena', 'Sofía']) + " " + \
                random.choice(['García', 'Rodríguez', 'López', 'Martínez', 'González'])
    else:
        nombre = random.choice(['Alex', 'Sam', 'Jordan', 'Taylor', 'Casey']) + " " + \
                random.choice(['García', 'Rodríguez', 'López', 'Martínez', 'González'])

    email = nombre.lower().replace(' ', '.') + f"{i}@ejemplo.com"
    ciudad = random.choice(['Madrid', 'Barcelona', 'Valencia', 'Sevilla', 'Bilbao'])
    pais = 'España'
    edad = random.randint(18, 70)
    fecha_registro = datetime.now() - timedelta(days=random.randint(1, 365*2))

    clientes.append({
        'nombre': nombre,
        'email': email,
        'fecha_registro': fecha_registro,
        'ciudad': ciudad,
        'pais': pais,
        'genero': genero,
        'edad': edad
    })

df_clientes = pd.DataFrame(clientes)
df_clientes.to_csv('clientes.csv', index=False)

# %%
# Cargar categorías
df_categorias = pd.read_csv("categorias.csv")
df_categorias.to_sql("categorias", engine, schema="ecommerce", if_exists="append", index=False)
# Out:
# 5

# %%
# Cargar productos
df_productos= pd.read_csv("productos.csv")
df_productos.to_sql("productos", engine, schema="ecommerce", if_exists="append", index=False)
# Out:
# 50

# %%
# Cargar clientes
df_clientes = pd.read_csv("clientes.csv")
df_clientes['fecha_registro'] = pd.to_datetime(df_clientes['fecha_registro'])
df_clientes.to_sql("clientes", engine, schema="ecommerce", if_exists="append", index=False)
# Out:
# 100

# %% [markdown]
# CREATE TABLE IF NOT EXISTS ecommerce.detalles_pedido (
#     id_detalle SERIAL PRIMARY KEY,
#     id_pedido INTEGER REFERENCES ecommerce.pedidos(id_pedido),
#     id_producto INTEGER REFERENCES ecommerce.productos(id_producto),
#     cantidad INTEGER NOT NULL,
#     precio_unitario NUMERIC(10,2) NOT NULL,
#     subtotal NUMERIC(12,2) NOT NULL

# %%
# Ahora generemos pedidos y sus detalles directamente
np.random.seed(42)
fecha_inicio = datetime.now() - timedelta(days=365)  # Un año de datos

# Generamos 500 pedidos
pedidos = []
detalles_pedido = []

for i in range(1, 501):
    id_cliente = random.randint(1, 100)
    fecha_pedido = fecha_inicio + timedelta(days=random.randint(0, 364))
    estado = random.choice(['Pendiente', 'Enviado', 'Entregado', 'Cancelado'])
    metodo_pago = random.choice(['Tarjeta', 'PayPal', 'Transferencia', 'Contra reembolso'])

    # Entre 1 y 5 productos por pedido
    num_productos = random.randint(1, 5)
    subtotal_pedido = 0

    # Este pedido irá a la tabla de pedidos
    pedidos.append({
        'id_cliente': id_cliente,
        'fecha_pedido': fecha_pedido,
        'estado': estado,
        'metodo_pago': metodo_pago,
        'total': 0  # Lo actualizaremos después
    })

    # Generar los detalles (líneas) del pedido
    for j in range(num_productos):
        id_producto = random.randint(1, 50)
        cantidad = random.randint(1, 3)

        # Obtener el precio del producto
        precio = df_productos.loc[id_producto-1, 'precio']
        subtotal = precio * cantidad
        subtotal_pedido += subtotal

        # Este detalle irá a la tabla de detalles_pedido
        detalles_pedido.append({
            'id_pedido': i,
            'id_producto': id_producto,
            'cantidad': cantidad,
            'precio_unitario': precio,
            'subtotal': subtotal
        })

    # Actualizar el total del pedido
    pedidos[i-1]['total'] = subtotal_pedido

# Convertir a DataFrames
df_pedidos = pd.DataFrame(pedidos)
df_detalles = pd.DataFrame(detalles_pedido)

df_pedidos.to_csv('pedidos.csv', index=False)
df_detalles.to_csv('detalles_pedido.csv', index=False)

# Cargar a la base de datos
df_pedidos.to_sql('pedidos', engine, schema='ecommerce', if_exists='append', index=False)
df_detalles.to_sql('detalles_pedido', engine, schema='ecommerce', if_exists='append', index=False)
# Out:
# 442

# %%
# Análisis de ventas por categoría y mes

query_ventas_categoria = """ SELECT c.nombre as categoria, 
                                DATE_TRUNC('month', 
                                p.fecha_pedido)::date as mes, 
                                COUNT(DISTINCT p.id_pedido) as num_pedidos, 
                                SUM(dp.subtotal) as ingresos, 
                                SUM(dp.cantidad) as unidades_vendidas 
                            FROM ecommerce.detalles_pedido dp 
                            JOIN ecommerce.pedidos p ON dp.id_pedido = p.id_pedido 
                            JOIN ecommerce.productos pr ON dp.id_producto = pr.id_producto 
                            JOIN ecommerce.categorias c ON pr.id_categoria = c.id_categoria 
                            WHERE p.estado != 'Cancelado' 
                            GROUP BY c.nombre, DATE_TRUNC('month', p.fecha_pedido)::date 
                            ORDER BY mes, categoria 

                        """

df_ventas_categoria = pd.read_sql(query_ventas_categoria, engine)
df_ventas_categoria
# Out:
#       categoria         mes  num_pedidos  ingresos  unidades_vendidas
# 0      Deportes  2024-04-01            1    506.10                  2
# 1         Hogar  2024-04-01            1   1856.43                  4
# 2        Libros  2024-04-01            1     35.89                  1
# 3          Ropa  2024-04-01            1     75.27                  3
# 4      Deportes  2024-05-01           16  10524.43                 46
# ..          ...         ...          ...       ...                ...
# 59     Deportes  2025-04-01           19  12302.72                 53
# 60  Electrónica  2025-04-01            8  18627.86                 22
# 61        Hogar  2025-04-01           12  11816.84                 27
# 62       Libros  2025-04-01           14   1096.91                 38
# 63         Ropa  2025-04-01            4    831.19                  7
#
# [64 rows x 5 columns]

# %%
# Análisis de rentabilidad de productos
query_basica_ventas = """
SELECT
    pr.id_producto,
    pr.nombre,
    SUM(dp.cantidad) as unidades_vendidas
FROM ecommerce.detalles_pedido dp
JOIN ecommerce.productos pr ON dp.id_producto = pr.id_producto
GROUP BY pr.id_producto, pr.nombre
ORDER BY unidades_vendidas DESC

"""

df_ventas_basica = pd.read_sql(query_basica_ventas, engine)
df_ventas_basica
# Out:
#     id_producto                nombre  unidades_vendidas
# 0            15        Novela Vol. 15                 89
# 1             2         Novela Vol. 2                 80
# 2            43       Vajilla Home 43                 77
# 3             5        Lámpara Home 5                 76
# 4            21          Mesa Home 21                 76
# 5            50          Balón Pro 50                 76
# 6            35        Cocina Vol. 35                 75
# 7            11       Lámpara Home 11                 73
# 8            33  Smartwatch Modelo 33                 73
# 9            19     Mancuernas Pro 19                 71
# 10           28     Vestido Estilo 28                 69
# 11           37       Vajilla Home 37                 69
# 12           10       Ciencia Vol. 10                 68
# 13           44    Chaqueta Estilo 44                 66
# 14           30      Bicicleta Pro 30                 65
# 15           14          Balón Pro 14                 65
# 16            9      Zapatos Estilo 9                 64
# 17           39          Balón Pro 39                 60
# 18           12  Smartwatch Modelo 12                 60
# 19           42          Mesa Home 42                 60
# 20            3        Ciencia Vol. 3                 60
# 21           49       Vajilla Home 49                 58
# 22           13          Balón Pro 13                 58
# 23           47          Mesa Home 47                 56
# 24           26       Lámpara Home 26                 56
# 25            4       Bicicleta Pro 4                 56
# 26           17     Vestido Estilo 17                 56
# 27           29       Vajilla Home 29                 55
# 28           32      Historia Vol. 32                 55
# 29           31        Cocina Vol. 31                 55
# 30           27      Cortinas Home 27                 55
# 31            7      Zapatos Estilo 7                 54
# 32           24          Mesa Home 24                 53
# 33           34          Balón Pro 34                 52
# 34           25     Zapatillas Pro 25                 52
# 35           22      Cortinas Home 22                 51
# 36           45     Mancuernas Pro 45                 51
# 37           48  Smartwatch Modelo 48                 50
# 38            6      Biografía Vol. 6                 50
# 39            1   Smartphone Modelo 1                 47
# 40           16     Zapatillas Pro 16                 46
# 41           36     Zapatillas Pro 36                 45
# 42           23     Mancuernas Pro 23                 44
# 43           46        Raqueta Pro 46                 44
# 44           38     Zapatillas Pro 38                 43
# 45            8         Cocina Vol. 8                 40
# 46           20  Smartphone Modelo 20                 38
# 47           18      Cortinas Home 18                 36
# 48           41          Mesa Home 41                 33
# 49           40      Historia Vol. 40                 33

# %%
info_por_categorias = """
SELECT
    pr.id_producto,
    pr.nombre,
    c.nombre as categoria,
    SUM(dp.cantidad) as unidades_vendidas
FROM ecommerce.detalles_pedido dp
JOIN ecommerce.productos pr ON dp.id_producto = pr.id_producto
JOIN ecommerce.categorias c ON pr.id_categoria = c.id_categoria
GROUP BY pr.id_producto, pr.nombre, c.nombre
ORDER BY unidades_vendidas DESC

"""

info_por_categorias = pd.read_sql(info_por_categorias, engine)
info_por_categorias
# Out:
#     id_producto                nombre    categoria  unidades_vendidas
# 0            15        Novela Vol. 15       Libros                 89
# 1             2         Novela Vol. 2       Libros                 80
# 2            43       Vajilla Home 43        Hogar                 77
# 3            50          Balón Pro 50     Deportes                 76
# 4             5        Lámpara Home 5        Hogar                 76
# 5            21          Mesa Home 21        Hogar                 76
# 6            35        Cocina Vol. 35       Libros                 75
# 7            11       Lámpara Home 11        Hogar                 73
# 8            33  Smartwatch Modelo 33  Electrónica                 73
# 9            19     Mancuernas Pro 19     Deportes                 71
# 10           28     Vestido Estilo 28         Ropa                 69
# 11           37       Vajilla Home 37        Hogar                 69
# 12           10       Ciencia Vol. 10       Libros                 68
# 13           44    Chaqueta Estilo 44         Ropa                 66
# 14           14          Balón Pro 14     Deportes                 65
# 15           30      Bicicleta Pro 30     Deportes                 65
# 16            9      Zapatos Estilo 9         Ropa                 64
# 17            3        Ciencia Vol. 3       Libros                 60
# 18           42          Mesa Home 42        Hogar                 60
# 19           12  Smartwatch Modelo 12  Electrónica                 60
# 20           39          Balón Pro 39     Deportes                 60
# 21           49       Vajilla Home 49        Hogar                 58
# 22           13          Balón Pro 13     Deportes                 58
# 23           17     Vestido Estilo 17         Ropa                 56
# 24           47          Mesa Home 47        Hogar                 56
# 25           26       Lámpara Home 26        Hogar                 56
# 26            4       Bicicleta Pro 4     Deportes                 56
# 27           32      Historia Vol. 32       Libros                 55
# 28           29       Vajilla Home 29        Hogar                 55
# 29           31        Cocina Vol. 31       Libros                 55
# 30           27      Cortinas Home 27        Hogar                 55
# 31            7      Zapatos Estilo 7         Ropa                 54
# 32           24          Mesa Home 24        Hogar                 53
# 33           34          Balón Pro 34     Deportes                 52
# 34           25     Zapatillas Pro 25     Deportes                 52
# 35           22      Cortinas Home 22        Hogar                 51
# 36           45     Mancuernas Pro 45     Deportes                 51
# 37            6      Biografía Vol. 6       Libros                 50
# 38           48  Smartwatch Modelo 48  Electrónica                 50
# 39            1   Smartphone Modelo 1  Electrónica                 47
# 40           16     Zapatillas Pro 16     Deportes                 46
# 41           36     Zapatillas Pro 36     Deportes                 45
# 42           23     Mancuernas Pro 23     Deportes                 44
# 43           46        Raqueta Pro 46     Deportes                 44
# 44           38     Zapatillas Pro 38     Deportes                 43
# 45            8         Cocina Vol. 8       Libros                 40
# 46           20  Smartphone Modelo 20  Electrónica                 38
# 47           18      Cortinas Home 18        Hogar                 36
# 48           40      Historia Vol. 40       Libros                 33
# 49           41          Mesa Home 41        Hogar                 33

# %%
filtrar_pedidos_cancelados = """
SELECT
    pr.id_producto,
    pr.nombre,
    c.nombre as categoria,
    SUM(dp.cantidad) as unidades_vendidas
FROM ecommerce.detalles_pedido dp
JOIN ecommerce.productos pr ON dp.id_producto = pr.id_producto
JOIN ecommerce.pedidos p ON dp.id_pedido = p.id_pedido 
JOIN ecommerce.categorias c ON pr.id_categoria = c.id_categoria
WHERE p.estado != 'Cancelado' 
GROUP BY pr.id_producto, pr.nombre, c.nombre
ORDER BY unidades_vendidas DESC

"""
filtrar_pedidos_cancelados = pd.read_sql(filtrar_pedidos_cancelados, engine)
filtrar_pedidos_cancelados
# Out:
#     id_producto                nombre    categoria  unidades_vendidas
# 0            15        Novela Vol. 15       Libros                 76
# 1             2         Novela Vol. 2       Libros                 68
# 2             5        Lámpara Home 5        Hogar                 67
# 3            35        Cocina Vol. 35       Libros                 66
# 4            50          Balón Pro 50     Deportes                 64
# 5            37       Vajilla Home 37        Hogar                 60
# 6            21          Mesa Home 21        Hogar                 56
# 7            11       Lámpara Home 11        Hogar                 56
# 8            33  Smartwatch Modelo 33  Electrónica                 55
# 9            43       Vajilla Home 43        Hogar                 55
# 10           19     Mancuernas Pro 19     Deportes                 55
# 11           28     Vestido Estilo 28         Ropa                 55
# 12           10       Ciencia Vol. 10       Libros                 53
# 13           32      Historia Vol. 32       Libros                 52
# 14            9      Zapatos Estilo 9         Ropa                 51
# 15           39          Balón Pro 39     Deportes                 50
# 16           13          Balón Pro 13     Deportes                 48
# 17           44    Chaqueta Estilo 44         Ropa                 47
# 18            3        Ciencia Vol. 3       Libros                 47
# 19           17     Vestido Estilo 17         Ropa                 47
# 20           27      Cortinas Home 27        Hogar                 47
# 21           30      Bicicleta Pro 30     Deportes                 47
# 22           12  Smartwatch Modelo 12  Electrónica                 46
# 23           24          Mesa Home 24        Hogar                 45
# 24           48  Smartwatch Modelo 48  Electrónica                 44
# 25           29       Vajilla Home 29        Hogar                 44
# 26           49       Vajilla Home 49        Hogar                 44
# 27           34          Balón Pro 34     Deportes                 44
# 28           22      Cortinas Home 22        Hogar                 43
# 29            4       Bicicleta Pro 4     Deportes                 43
# 30           47          Mesa Home 47        Hogar                 43
# 31           26       Lámpara Home 26        Hogar                 42
# 32            6      Biografía Vol. 6       Libros                 41
# 33           14          Balón Pro 14     Deportes                 41
# 34           16     Zapatillas Pro 16     Deportes                 40
# 35           36     Zapatillas Pro 36     Deportes                 40
# 36           31        Cocina Vol. 31       Libros                 40
# 37           45     Mancuernas Pro 45     Deportes                 39
# 38           25     Zapatillas Pro 25     Deportes                 38
# 39           42          Mesa Home 42        Hogar                 37
# 40           23     Mancuernas Pro 23     Deportes                 36
# 41            1   Smartphone Modelo 1  Electrónica                 34
# 42            7      Zapatos Estilo 7         Ropa                 34
# 43           20  Smartphone Modelo 20  Electrónica                 31
# 44           46        Raqueta Pro 46     Deportes                 29
# 45           41          Mesa Home 41        Hogar                 29
# 46           18      Cortinas Home 18        Hogar                 28
# 47            8         Cocina Vol. 8       Libros                 28
# 48           40      Historia Vol. 40       Libros                 27
# 49           38     Zapatillas Pro 38     Deportes                 25

# %%
query_rentabilidad = """
WITH ventas_producto AS (
SELECT
    pr.id_producto,
    pr.nombre,
    c.nombre as categoria,
    SUM(dp.cantidad) as unidades_vendidas,
    SUM(dp.subtotal) as ingresos,
    sum(dp.cantidad * pr.costo) as costo_total
FROM ecommerce.detalles_pedido dp
JOIN ecommerce.productos pr ON dp.id_producto = pr.id_producto
JOIN ecommerce.pedidos p ON dp.id_pedido = p.id_pedido 
JOIN ecommerce.categorias c ON pr.id_categoria = c.id_categoria
WHERE p.estado != 'Cancelado' 
GROUP BY pr.id_producto, pr.nombre, c.nombre
)
SELECT
    id_producto,
    nombre,
    unidades_vendidas,
    costo_total,
    (ingresos - costo_total) as beneficio,
    CASE WHEN ingresos > 0
        THEN ROUND (((ingresos - costo_total) / ingresos) * 100, 2)
        ELSE 0 END as margen_porcentaje
FROM ventas_producto
ORDER BY beneficio DESC

"""
df_rentabilidad = pd.read_sql(query_rentabilidad, engine)
df_rentabilidad
# Out:
#     id_producto                nombre  unidades_vendidas  costo_total  \
# 0            12  Smartwatch Modelo 12                 46     40830.52
# 1             5        Lámpara Home 5                 67     27685.74
# 2            24          Mesa Home 24                 45     14773.95
# 3            48  Smartwatch Modelo 48                 44     37722.08
# 4            33  Smartwatch Modelo 33                 55     11994.95
# 5            21          Mesa Home 21                 56     12869.36
# 6            29       Vajilla Home 29                 44     19022.08
# 7            49       Vajilla Home 49                 44     13425.72
# 8            43       Vajilla Home 43                 55     23020.25
# 9            13          Balón Pro 13                 48      9654.24
# 10           18      Cortinas Home 18                 28      8654.24
# 11           47          Mesa Home 47                 43      9865.06
# 12           27      Cortinas Home 27                 47      9329.97
# 13           34          Balón Pro 34                 44     10747.00
# 14           26       Lámpara Home 26                 42      6379.80
# 15            4       Bicicleta Pro 4                 43      6496.87
# 16           41          Mesa Home 41                 29     10191.76
# 17           50          Balón Pro 50                 64      6839.68
# 18           20  Smartphone Modelo 20                 31     17022.41
# 19           37       Vajilla Home 37                 60      8117.40
# 20           42          Mesa Home 42                 37     11673.13
# 21           11       Lámpara Home 11                 56     11799.20
# 22           22      Cortinas Home 22                 43      8223.75
# 23           39          Balón Pro 39                 50      7848.00
# 24            1   Smartphone Modelo 1                 34      7741.46
# 25           25     Zapatillas Pro 25                 38      7208.22
# 26           30      Bicicleta Pro 30                 47      7730.09
# 27           46        Raqueta Pro 46                 29      3556.27
# 28           36     Zapatillas Pro 36                 40      6127.60
# 29           45     Mancuernas Pro 45                 39      3275.22
# 30           17     Vestido Estilo 17                 47      3295.64
# 31           14          Balón Pro 14                 41      3373.48
# 32            9      Zapatos Estilo 9                 51      4286.04
# 33           28     Vestido Estilo 28                 55      1802.35
# 34           23     Mancuernas Pro 23                 36      3205.08
# 35           15        Novela Vol. 15                 76      1237.28
# 36           16     Zapatillas Pro 16                 40      1960.40
# 37           38     Zapatillas Pro 38                 25      2249.50
# 38            7      Zapatos Estilo 7                 34      2828.12
# 39           32      Historia Vol. 32                 52      1308.32
# 40           19     Mancuernas Pro 19                 55       733.15
# 41            3        Ciencia Vol. 3                 47      1318.35
# 42           10       Ciencia Vol. 10                 53       620.10
# 43           31        Cocina Vol. 31                 40       979.60
# 44            6      Biografía Vol. 6                 41       578.10
# 45            2         Novela Vol. 2                 68       848.64
# 46           35        Cocina Vol. 35                 66       566.28
# 47           44    Chaqueta Estilo 44                 47       824.38
# 48            8         Cocina Vol. 8                 28       261.24
# 49           40      Historia Vol. 40                 27       422.01
#
#     beneficio  margen_porcentaje
# 0    22381.76              35.41
# 1    17520.50              38.76
# 2    17470.35              54.18
# 3    17247.12              31.38
# 4    16838.25              58.40
# 5    15619.52              54.83
# 6    14870.24              43.87
# 7    13100.56              49.39
# 8    12812.80              35.76
# 9    12638.40              56.69
# 10   12162.08              58.43
# 11   11641.39              54.13
# 12   10710.36              53.44
# 13    9616.20              47.22
# 14    9492.42              59.81
# 15    8977.54              58.02
# 16    8642.00              45.89
# 17    8491.52              55.39
# 18    7618.56              30.92
# 19    6822.00              45.66
# 20    6561.95              35.99
# 21    5173.84              30.48
# 22    5009.93              37.86
# 23    4804.50              37.97
# 24    4185.40              35.09
# 25    4107.42              36.30
# 26    3977.61              33.97
# 27    3524.37              49.77
# 28    3053.20              33.26
# 29    2935.92              47.27
# 30    2811.07              46.03
# 31    2405.06              41.62
# 32    2079.27              32.67
# 33    1823.80              50.30
# 34    1695.96              34.60
# 35    1490.36              54.64
# 36    1407.20              41.79
# 37    1280.25              36.27
# 38    1276.70              31.10
# 39    1082.64              45.28
# 40    1075.25              59.46
# 41     803.23              37.86
# 42     697.48              52.94
# 43     582.00              37.27
# 44     546.94              48.62
# 45     410.04              32.58
# 46     378.18              40.04
# 47     354.85              30.09
# 48     308.84              54.17
# 49     296.73              41.28
